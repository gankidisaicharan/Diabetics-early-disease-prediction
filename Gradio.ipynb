# %% [markdown]
# <a href="https://colab.research.google.com/github/gankidisaicharan/Diabetics-early-disease-prediction/blob/main/Gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 70.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.9/287.9 kB 29.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 13.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import gradio as gr
from joblib import load
from sklearn.preprocessing import LabelEncoder
# Load the model and data
model = load('/content/drive/MyDrive/PROJECTS/Diabetics Early disease prediction/Models/XGBoost.pkl')
df = pd.read_csv("/content/drive/MyDrive/PROJECTS/Diabetics Early disease prediction/diabetes_prediction_dataset.csv")

gender_le=LabelEncoder()
smoking_history_le=LabelEncoder()
df['gender'] = gender_le.fit_transform(df['gender'])
df['smoking_history'] = smoking_history_le.fit_transform(df['smoking_history'])
df = pd.read_csv("/content/drive/MyDrive/PROJECTS/Diabetics Early disease prediction/diabetes_prediction_dataset.csv")
# Create input objects for the interface
gender = gr.inputs.Dropdown(choices=list(df['gender'].unique()), label='Gender')
age = gr.inputs.Slider(0, 100, default=20, label="Age")
hypertension = gr.inputs.Checkbox(label='Hyper Tension (select if you have Hyper tension)')
heart_disease =gr.inputs.Checkbox(label='Heart Disease (select if you have Heart disease)')
smoking_history = gr.inputs.Dropdown(choices=list(df['smoking_history'].unique()), label='Smoking History')
bmi = gr.inputs.Slider(0, 100, default=27, label="BMI")
HbA1c_level = gr.inputs.Slider(3, 9, default=4, label="Hemoglobin A1c Level")
blood_glucose_level = gr.inputs.Slider(80, 300, default=140, step=1, label='Blood Glucose Level')
output = gr.outputs.Textbox(label='Predicted diabetes')

# Define the predict function
def predict_diabetes(gender, age, hypertension, heart_disease, smoking_history, bmi, HbA1c_level, blood_glucose_level):
    gender = gender_le.transform([gender])[0]
    smoking_history = smoking_history_le.transform([smoking_history])[0]

    custom_input = pd.DataFrame({
        'gender': [gender],
        'age': [age],
        'hypertension': [hypertension],
        'heart_disease': [heart_disease],
        'smoking_history': [smoking_history],
        'bmi': [bmi],
        'HbA1c_level': [HbA1c_level],
        'blood_glucose_level': [blood_glucose_level]
    })
    pred_proba = model.predict_proba(custom_input)[:, 1]
    return 'Diabetes probability: {:.2f}%'.format(pred_proba[0] * 100)

# Create the interface
interface = gr.Interface(fn=predict_diabetes, inputs=[gender, age, hypertension, heart_disease, smoking_history, bmi, HbA1c_level, blood_glucose_level], outputs=output,title="Early Prediction of Diabetes",description="Enter following details to check you have Diabetes or Not")
interface.launch(debug=True,share=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:219: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:89: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gradio/inputs.py:121: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# ...

# %%
log=pd.read_csv("/content/flagged/log.csv")
log
# Out:
#   Gender  Age  Hyper Tension (select if you have Hyper tension)  \
# 0   Male   29                                              True
#
#    Heart Disease (select if you have Heart disease) Smoking History  BMI  \
# 0                                             False         current   27
#
#    Hemoglobin A1c Level  Blood Glucose Level           Predicted diabetes  \
# 0                     4                  140  Diabetes probability: 0.36%
#
#    flag  username                   timestamp
# 0   NaN       NaN  2023-04-28 19:17:32.759694
